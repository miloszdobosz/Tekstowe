# %% [markdown]
# ## Funkcje do wizualizacji

# %%
from IPython.display import display
from graphviz import Source

# %%
class Node:
    counter = 1
    
    def __init__(self, label, depth):
        self.children = {}
        self.label = label
        self.link = None
        self.id = Node.counter
        self.depth = depth
        Node.counter += 1
        
    def dot_node(self):
        return f'{self.id} [label="", shape="point"];'
        
    def dot_edges(self, links=True):
        result = []
        for child in self.children.values():
            result.append(f'{self.id} -> {child.id}[arrowhead="none", label=" {child.label}"];')
        if self.link and links:
            result.append(f'{self.id} -> {self.link.id}[color="blue"];')
        return "\n".join(result)
    
    def all_children(self, only_leafs=False):
        if(not only_leafs or not self.children):
            result = [self]
        else:
            result = []
        for child in self.children.values():
            result += child.all_children(only_leafs=only_leafs)
        return result
    
    def show(self, links=True):
        nodes = self.all_children()
        Node.show_graph(nodes, links=links)
    
    @staticmethod
    def show_graph(nodes, links=True):
        result = "digraph{\n"
        ranks = {}
        for node in nodes:
            result += node.dot_node() + "\n"
            result += node.dot_edges(links) + "\n"
            if(node.depth not in ranks):
                ranks[node.depth] = []
            ranks[node.depth].append(node.id)
        for key, values in ranks.items():
            values = " ".join([f"{v};" for v in values])
            result += " { rank=same; " + values + "}\n"
        result += "\n}"
        s = Source(result)
        display(s)

# %% [markdown]
# ## Implementacje algorytmów
# Budowanie drzewa trie w czasie O(n\*\*2) oraz pamięci O(n\*\*2):

# %%
def trie(data):
    root = Node("", 0)

    for i in range(len(data)):
        current = root

        for j, letter in enumerate(data[i:]):
            if not letter in current.children:
                current.children[letter] = Node(letter, j)
            
            current = current.children[letter]

    return root

# %% [markdown]
# Budowanie drzewa suffixów w czasie O(n\*\*2) oraz pamięci O(n):

# %%
def add_suffix(data, current, i):
    length = len(data)
    
    while i < length:
        if data[i] in current.children:
            current = current.children[data[i]]
            a, b = current.label

            for j in range(a, b):
                if data[j] != data[i]:
                    # Add node:
                    
                    current.label = (a, j)

                    old = Node((j, b), j)
                    old.children = current.children

                    new = Node((i, length), i)

                    current.children = {
                        data[j]: old,
                        data[i]: new
                    }
                    return

                i += 1
        else:
            # Add child:
            
            current.children[data[i]] = Node((i, length), i)
            return
                

def suffix_tree(data):
    root = Node((), 0)

    for i in range(len(data)):
        add_suffix(data, root, i)

    return root

# %% [markdown]
# ## Tworzenie danych

# %%
data = [
    "bbb$",
    "aabbabd",
    "ababcd",
    "abcbccd",
    open("1997_714_head.txt", "r").read() + "$"
]

# %% [markdown]
# ## Wizualizacja

# %%
for d in data:
    print("Dane:\n")
    print(d)
    print("\nTrie:")
    trie(d).show()
    print("\nSuffix tree:")
    suffix_tree(d).show()
# Out:
# Dane:
#
# bbb$
#
# Trie:
# Suffix tree:
# Dane:
#
# aabbabd
#
# Trie:
# Suffix tree:
# Dane:
#
# ababcd
#
# Trie:
# Suffix tree:
# Dane:
#
# abcbccd
#
# Trie:
# Suffix tree:
# Dane:
#
#
#
#
#
# Dz.U. z 1998 r. Nr 144, poz. 930
#
#
#
#
#                                     USTAWA
#                           z dnia 20 listopada 1998 r.
#
#          o zryczałtowanym podatku dochodowym od niektórych przychodów
#                         osiąganych przez osoby fizyczne
#
#                                   Rozdział 1
#                                 Przepisy ogólne
#
#                                     Art. 1.
# Ustawa reguluje opodatkowanie zryczałtowanym podatkiem dochodowym niektórych
# przychodów (dochodów) osiąganych przez osoby fizyczne prowadzące pozarolniczą
# działalność gospodarczą oraz przez osoby duchowne.
#
#                                     Art. 2.
# 1. Osoby fizyczne osiągające przychody z pozarolniczej działalności
# ...

# %% [markdown]
# ## Pomiary

# %%
import time

# %%
def measure(function):
    start = time.time()
    function()
    return time.time() - start

def measure_all(data):
    return [
        (
            measure(lambda: trie(d)),
            measure(lambda: suffix_tree(d))
        ) for d in data
    ]

def show_times(data, times):
    for d, t in zip(data, times):
        print(
            "Dla danych:\t\t\t" +
            str(d) +
            "\n\nO długości:\t\t\t" +
            str(len(d)) +
            "\n\nAlgorytm trie zajmuje:\t\t" +
            str(t[0]) +
            " s.\nAlgorytm suffix_tree zajmuje:\t" +
            str(t[1]) +
            " s.\n\nPierwszy czas / drugi czas:\t" +
            str(round(t[0]/t[1], 2)) +
            "\n\n\n"
        )

# %%
times = measure_all(data)

# %%
show_times(data, times)
# Out:
# Dla danych:			bbb$
#
# O długości:			4
#
# Algorytm trie zajmuje:		6.628036499023438e-05 s.
# Algorytm suffix_tree zajmuje:	4.887580871582031e-05 s.
#
# Pierwszy czas / drugi czas:	1.36
#
#
#
# Dla danych:			aabbabd
#
# O długości:			7
#
# Algorytm trie zajmuje:		0.00010633468627929688 s.
# Algorytm suffix_tree zajmuje:	6.318092346191406e-05 s.
#
# Pierwszy czas / drugi czas:	1.68
#
#
#
# Dla danych:			ababcd
#
# O długości:			6
#
# Algorytm trie zajmuje:		7.987022399902344e-05 s.
# Algorytm suffix_tree zajmuje:	4.5299530029296875e-05 s.
#
# Pierwszy czas / drugi czas:	1.76
#
#
#
# Dla danych:			abcbccd
#
# O długości:			7
#
# Algorytm trie zajmuje:		0.00010251998901367188 s.
# Algorytm suffix_tree zajmuje:	5.125999450683594e-05 s.
#
# Pierwszy czas / drugi czas:	2.0
#
#
#
# Dla danych:
#
#
#
# Dz.U. z 1998 r. Nr 144, poz. 930
#
#
#
#
#                                     USTAWA
#                           z dnia 20 listopada 1998 r.
#
# ...
